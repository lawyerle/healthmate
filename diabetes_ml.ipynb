# %%
import pandas as pd
import numpy as np

diabete_df = pd.read_csv("diabetes.csv")

diabete_df.head()
# Out:
#      id   chol  stab.glu   hdl  ratio  glyhb    location  age  gender  height  \
# 0  1000  203.0        82  56.0    3.6   4.31  Buckingham   46  female    62.0
# 1  1001  165.0        97  24.0    6.9   4.44  Buckingham   29  female    64.0
# 2  1002  228.0        92  37.0    6.2   4.64  Buckingham   58  female    61.0
# 3  1003   78.0        93  12.0    6.5   4.63  Buckingham   67    male    67.0
# 4  1005  249.0        90  28.0    8.9   7.72  Buckingham   64    male    68.0
#
#    weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist   hip  time.ppn
# 0   121.0  medium  118.0   59.0    NaN    NaN   29.0  38.0     720.0
# 1   218.0   large  112.0   68.0    NaN    NaN   46.0  48.0     360.0
# 2   256.0   large  190.0   92.0  185.0   92.0   49.0  57.0     180.0
# 3   119.0   large  110.0   50.0    NaN    NaN   33.0  38.0     480.0
# 4   183.0  medium  138.0   80.0    NaN    NaN   44.0  41.0     300.0

# %%
diabete_df.describe()

# %% [markdown]
# 1. What is our target?
#  	- As we can seen in the main dataset description, the variable "glyhb" is our target. 정상인 : 7% 당뇨병환자 : 14.5%
# 2. List of features
# 	- chol = Cholesterol
# 	- stab.glu = Stabilized Glucose
# 	- hdl = High Density Lipoprotein Cholesterol
# 	- Ratio
# 	- Age and Gender
# 	- Height and Weight
# 	- Frame
# 	- bp.1s = First diastolic blood pressure
# 	- bp.1d = First systolic blood pressure
# 	- Waist
# 	- hip = Hybrid insulin peptides
# 	- time.ppn = Partial parenteral nutrition

# %% [markdown]
# 1. What is our target?
#  	- As we can seen in the main dataset description, the variable "glyhb" is our target. 정상인 : 7% 당뇨병환자 : 14.5%
# 2. List of features
# 	- chol = Cholesterol
# 	- stab.glu = Stabilized Glucose
# 	- hdl = High Density Lipoprotein Cholesterol
# 	- Ratio
# 	- Age and Gender
# 	- Height and Weight
# 	- Frame
# 	- bp.1s = First diastolic blood pressure
# 	- bp.1d = First systolic blood pressure
# 	- Waist
# 	- hip = Hybrid insulin peptides
# 	- time.ppn = Partial parenteral nutrition

# %%
features = ['chol', 'stb.glu', 'hdl', 'ratio', 'age', 'gender', 'height', 'weight',	'frame', 'bp.1s', 'bp.1d', 'bp.2s', 'bp.2d', 'waist', 'hip', 'time.ppn']

target = 'glyhb'
